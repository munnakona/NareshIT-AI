# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r'/Users/munna/VScode/NareshIT-AI/Deep Learning/OpenCV/Photo.jpeg')

# %%
input
# Out:
# array([[[173,  89,  37],
#         [183,  99,  47],
#         [176,  92,  40],
#         ...,
#         [231, 221, 204],
#         [230, 218, 206],
#         [226, 214, 204]],
#
#        [[175,  91,  39],
#         [175,  91,  39],
#         [179,  95,  43],
#         ...,
#         [226, 216, 199],
#         [231, 219, 207],
#         [226, 214, 204]],
#
#        [[179,  95,  43],
#         [171,  87,  35],
#         [172,  88,  36],
#         ...,
#         [223, 213, 196],
#         [232, 220, 208],
#         [228, 216, 206]],
#
#        ...,
#
#        [[208, 190, 189],
#         [217, 199, 198],
#         [213, 193, 192],
#         ...,
#         [139, 120, 145],
#         [143, 127, 151],
#         [147, 131, 155]],
#
#        [[222, 207, 205],
#         [228, 213, 211],
#         [227, 209, 208],
#         ...,
#         [132, 113, 138],
#         [142, 126, 150],
#         [146, 130, 154]],
#
#        [[227, 214, 212],
#         [226, 213, 211],
#         [222, 209, 207],
# ...

# %%
type(input)
# Out:
# numpy.ndarray

# %%
len(input)
# Out:
# 1195

# %%
cv2.imshow('Input Image', input)
cv2.waitKey(0)

cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# 27

# %%
cv2.destroyAllWindows()
