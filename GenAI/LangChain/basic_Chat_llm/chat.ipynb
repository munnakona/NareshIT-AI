# %%
pip install -U "langchain[openai]"
# Out:
# Requirement already satisfied: langchain[openai] in /opt/anaconda3/lib/python3.13/site-packages (1.2.10)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /opt/anaconda3/lib/python3.13/site-packages (from langchain[openai]) (1.2.17)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in /opt/anaconda3/lib/python3.13/site-packages (from langchain[openai]) (1.0.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/anaconda3/lib/python3.13/site-packages (from langchain[openai]) (2.12.5)
# Requirement already satisfied: langchain-openai in /opt/anaconda3/lib/python3.13/site-packages (from langchain[openai]) (1.1.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (0.6.2)
# Requirement already satisfied: packaging>=23.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain[openai]) (0.13.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.8->langchain[openai]) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /opt/anaconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.8->langchain[openai]) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.8->langchain[openai]) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.8->langchain[openai]) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/anaconda3/lib/python3.13/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain[openai]) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /opt/anaconda3/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain[openai]) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /opt/anaconda3/lib/python3.13/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain[openai]) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (0.23.0)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain[openai]) (4.12.1)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain[openai]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain[openai]) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain[openai]) (2.10)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain[openai]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[openai]) (2.3.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /opt/anaconda3/lib/python3.13/site-packages (from langchain-openai->langchain[openai]) (2.15.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from langchain-openai->langchain[openai]) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (0.12.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.13/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai->langchain[openai]) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/lib/python3.13/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai->langchain[openai]) (2024.11.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
model =  init_chat_model("gpt-5.2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 5
#       2 from langchain.chat_models import init_chat_model
#       4 os.environ["OPENAI_API_KEY"] = "YOUR_OPENAI_API_KEY"
# ----> 5 model =  init_chat_model("google/gemini-3.1-pro-preview", temperature=1.0, max_tokens=None, timeout=None, max_retries=2)
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain/chat_models/base.py:464, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     456     warnings.warn(
#     457         f"{config_prefix=} has been set but no fields are configurable. Set "
#     458         f"`configurable_fields=(...)` to specify the model params that are "
#     459         f"configurable.",
#     460         stacklevel=2,
#     461     )
#     463 if not configurable_fields:
# --> 464     return _init_chat_model_helper(
#     465         cast("str", model),
#     466         model_provider=model_provider,
#     467         **kwargs,
#     468     )
#     469 if model:
#     470     kwargs["model"] = model
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain/chat_models/base.py:486, in _init_chat_model_helper(model, model_provider, **kwargs)
#     480 def _init_chat_model_helper(
#     481     model: str,
#     482     *,
#     483     model_provider: str | None = None,
#     484     **kwargs: Any,
#     485 ) -> BaseChatModel:
# --> 486     model, model_provider = _parse_model(model, model_provider)
#     487     creator_func = _get_chat_model_creator(model_provider)
#     488     return creator_func(model=model, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain/chat_models/base.py:582, in _parse_model(model, model_provider)
#     574     supported_list = ", ".join(sorted(_BUILTIN_PROVIDERS))
#     575     msg = (
#     576         f"Unable to infer model provider for {model=}. "
#     577         f"Please specify 'model_provider' directly.\n\n"
#    (...)
#     580         f"https://docs.langchain.com/oss/python/integrations/providers"
#     581     )
# --> 582     raise ValueError(msg)
#     584 # Normalize provider name
#     585 model_provider = model_provider.replace("-", "_").lower()
#
# ValueError: Unable to infer model provider for model='google/gemini-3.1-pro-preview'. Please specify 'model_provider' directly.
#
# Supported providers: anthropic, azure_ai, azure_openai, bedrock, bedrock_converse, cohere, deepseek, fireworks, google_anthropic_vertex, google_genai, google_vertexai, groq, huggingface, ibm, mistralai, nvidia, ollama, openai, perplexity, together, upstage, xai
#
# For help with specific providers, see: https://docs.langchain.com/oss/python/integrations/providers

# %%
response = model.invoke("What is LangChain?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 response = model.invoke("What is LangChain?")
#       2 print(response)
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)
#     395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)
#    1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1386, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1384     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1385         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1386     raise e
#    1387 if (
#    1388     self.include_response_headers
#    1389     and raw_response is not None
#    1390     and hasattr(raw_response, "headers")
#    1391 ):
#    1392     generation_info = {"headers": dict(raw_response.headers)}
#
# File /opt/anaconda3/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1381, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1374         return _construct_lc_result_from_responses_api(
#    1375             response,
#    1376             schema=original_schema_obj,
#    1377             metadata=generation_info,
#    1378             output_version=self.output_version,
#    1379         )
#    1380     else:
# -> 1381         raw_response = self.client.with_raw_response.create(**payload)
#    1382         response = raw_response.parse()
#    1383 except Exception as e:
#
# File /opt/anaconda3/lib/python3.13/site-packages/openai/_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File /opt/anaconda3/lib/python3.13/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)
#    1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/lib/python3.13/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
